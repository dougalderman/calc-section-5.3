# %%
#Problem 53

# %%
t=var('t')

# %%
def E(t): return t*exp(-0.1*t)

# %%
plot(E(t),(t,0,100), fill=true, color='blue', legend_label='E(t)')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
int = integral(E(t), t, 0, oo)

# %%
int
# Out:
# 99.99999999999999
